# %%
## pip install lightgbm

# %%
## pip install catboost

# %%
## pip install ipywidgets

# %%
# pip install xgboost

# %%
import numpy as np
import pandas as pd
import lightgbm
from lightgbm import LGBMRegressor
import catboost
from catboost import CatBoostRegressor
import sklearn
from sklearn.model_selection import KFold
import IPython
from IPython.display import clear_output
import copy
import matplotlib.pyplot as plt
import datetime
from tqdm import tqdm
import xgboost
from xgboost import XGBRegressor

# %%
# import datasets
train = pd.read_csv('../dataset/train.csv')
test = pd.read_csv('../dataset/test.csv')
building = pd.read_csv('../dataset/building_info.csv')

# %%
display(train)
display(test)
# Out:
#           num_date_time  건물번호           일시  기온(C)  강수량(mm)  풍속(m/s)  습도(%)  \
# 0         1_20220601 00     1  20220601 00   18.6      NaN      0.9   42.0
# 1         1_20220601 01     1  20220601 01   18.0      NaN      1.1   45.0
# 2         1_20220601 02     1  20220601 02   17.7      NaN      1.5   45.0
# 3         1_20220601 03     1  20220601 03   16.7      NaN      1.4   48.0
# 4         1_20220601 04     1  20220601 04   18.4      NaN      2.8   43.0
# ...                 ...   ...          ...    ...      ...      ...    ...
# 203995  100_20220824 19   100  20220824 19   23.1      NaN      0.9   86.0
# 203996  100_20220824 20   100  20220824 20   22.4      NaN      1.3   86.0
# 203997  100_20220824 21   100  20220824 21   21.3      NaN      1.0   92.0
# 203998  100_20220824 22   100  20220824 22   21.0      NaN      0.3   94.0
# 203999  100_20220824 23   100  20220824 23   20.7      NaN      0.1   95.0
#
#         일조(hr)  일사(MJ/m2)  전력소비량(kWh)
# 0          NaN        NaN     1085.28
# 1          NaN        NaN     1047.36
# 2          NaN        NaN      974.88
# 3          NaN        NaN      953.76
# 4          NaN        NaN      986.40
# ...        ...        ...         ...
# 203995     0.5        NaN      881.04
# 203996     0.0        NaN      798.96
# 203997     NaN        NaN      825.12
# 203998     NaN        NaN      640.08
# 203999     NaN        NaN      540.24
#
# [204000 rows x 10 columns]
#          num_date_time  건물번호           일시  기온(C)  강수량(mm)  풍속(m/s)  습도(%)
# 0        1_20220825 00     1  20220825 00   23.5      0.0      2.2     72
# 1        1_20220825 01     1  20220825 01   23.0      0.0      0.9     72
# 2        1_20220825 02     1  20220825 02   22.7      0.0      1.5     75
# 3        1_20220825 03     1  20220825 03   22.1      0.0      1.3     78
# 4        1_20220825 04     1  20220825 04   21.8      0.0      1.0     77
# ...                ...   ...          ...    ...      ...      ...    ...
# 16795  100_20220831 19   100  20220831 19   22.5      0.0      0.9     84
# 16796  100_20220831 20   100  20220831 20   20.7      0.0      0.4     95
# 16797  100_20220831 21   100  20220831 21   20.2      0.0      0.4     98
# 16798  100_20220831 22   100  20220831 22   20.1      0.0      1.1     97
# 16799  100_20220831 23   100  20220831 23   19.1      0.0      0.1     99
#
# [16800 rows x 7 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204000 entries, 0 to 203999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   num_date_time  204000 non-null  object
#  1   건물번호           204000 non-null  int64
#  2   일시             204000 non-null  object
#  3   기온(C)          204000 non-null  float64
#  4   강수량(mm)        43931 non-null   float64
#  5   풍속(m/s)        203981 non-null  float64
#  6   습도(%)          203991 non-null  float64
#  7   일조(hr)         128818 non-null  float64
#  8   일사(MJ/m2)      116087 non-null  float64
#  9   전력소비량(kWh)     204000 non-null  float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 15.6+ MB

# %%
train_df = train.copy()

train_df = train_df.drop(columns =  ['num_date_time', '일조(hr)', '일사(MJ/m2)'])
train_df = train_df.rename(columns = {'기온(C)':'기온', '강수량(mm)':'강수량', '풍속(m/s)':'풍속', '습도(%)':'습도', '전력소비량(kWh)':'전력소비량'})

# %%
# # 결측치 처리
# def fill_missing_with_avg(df, columns):
#     for i in range(len(df)):
#         if pd.isna(df.loc[i, columns]):
#             prev_value = df.loc[i-1, columns]
#             next_value = df.loc[i+1, columns]
#             avg_value = (prev_value + next_value) / 2
#             if pd.isna(prev_value) or pd.isna(next_value):
#                 building_num = df.loc[i,:]['건물번호']
#                 date = df.loc[i,:]['일시'][:8]
#                 avg_value = df[(df['건물번호'] == building_num) & (df['일시'].str.contains(date))][columns].mean()

#             df.loc[i, columns] = avg_value

# fill_missing_with_avg(train_df, '풍속')
# fill_missing_with_avg(train_df, '습도')

# %%
## 일시 columns
train_df['일시'] = pd.to_datetime(train_df['일시'])
train_df['월'] = train_df['일시'].dt.month
train_df['일'] = train_df['일시'].dt.day
train_df['요일'] = train_df['일시'].dt.weekday
train_df['시간'] = train_df['일시'].dt.hour
train_df['날짜'] = train_df['일시'].dt.date

train_df['sin_요일'] = np.sin(2*np.pi*(train_df['요일'])/6)
train_df['cos_요일'] = np.cos(2*np.pi*(train_df['요일'])/6)
train_df['sin_시간'] = np.sin(2*np.pi*(train_df['시간'])/23)
train_df['cos_시간'] = np.cos(2*np.pi*(train_df['시간'])/23)
# train_df['sin_일'] = np.sin(2*np.pi*(train_df['일']-1)/30)
# train_df['cos_일'] = np.cos(2*np.pi*(train_df['일']-1)/30)
train_df['일수'] = train_df['일시'].dt.dayofyear

train_df['휴일'] = train_df['요일'].isin([5,6]).astype(int)
train_df.loc[(train_df['월'] == 6) & (train_df['일'] == 6), '휴일'] = 1
train_df.loc[(train_df['월'] == 8) & (train_df['일'] == 15), '휴일'] = 1

cat_month = pd.get_dummies(train_df['월'])
train_df = pd.concat([train_df, cat_month], axis = 1).drop(columns = ['월'])

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204000 entries, 0 to 203999
# Data columns (total 20 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   건물번호    204000 non-null  int64
#  1   일시      204000 non-null  datetime64[ns]
#  2   기온      204000 non-null  float64
#  3   강수량     43931 non-null   float64
#  4   풍속      203981 non-null  float64
#  5   습도      203991 non-null  float64
#  6   전력소비량   204000 non-null  float64
#  7   일       204000 non-null  int64
#  8   요일      204000 non-null  int64
#  9   시간      204000 non-null  int64
#  10  날짜      204000 non-null  object
#  11  sin_요일  204000 non-null  float64
#  12  cos_요일  204000 non-null  float64
#  13  sin_시간  204000 non-null  float64
#  14  cos_시간  204000 non-null  float64
#  15  일수      204000 non-null  int64
#  16  휴일      204000 non-null  int32
#  17  6       204000 non-null  uint8
#  18  7       204000 non-null  uint8
#  19  8       204000 non-null  uint8
# dtypes: datetime64[ns](1), float64(9), int32(1), int64(5), object(1), uint8(3)
# memory usage: 26.3+ MB

# %%
train_df.set_index(train_df['일시'], inplace = True)
train_df
# Out:
#                      건물번호                  일시    기온  강수량   풍속    습도    전력소비량  \
# 일시
# 2022-06-01 00:00:00     1 2022-06-01 00:00:00  18.6  NaN  0.9  42.0  1085.28
# 2022-06-01 01:00:00     1 2022-06-01 01:00:00  18.0  NaN  1.1  45.0  1047.36
# 2022-06-01 02:00:00     1 2022-06-01 02:00:00  17.7  NaN  1.5  45.0   974.88
# 2022-06-01 03:00:00     1 2022-06-01 03:00:00  16.7  NaN  1.4  48.0   953.76
# 2022-06-01 04:00:00     1 2022-06-01 04:00:00  18.4  NaN  2.8  43.0   986.40
# ...                   ...                 ...   ...  ...  ...   ...      ...
# 2022-08-24 19:00:00   100 2022-08-24 19:00:00  23.1  NaN  0.9  86.0   881.04
# 2022-08-24 20:00:00   100 2022-08-24 20:00:00  22.4  NaN  1.3  86.0   798.96
# 2022-08-24 21:00:00   100 2022-08-24 21:00:00  21.3  NaN  1.0  92.0   825.12
# 2022-08-24 22:00:00   100 2022-08-24 22:00:00  21.0  NaN  0.3  94.0   640.08
# 2022-08-24 23:00:00   100 2022-08-24 23:00:00  20.7  NaN  0.1  95.0   540.24
#
#                       일  요일  시간          날짜    sin_요일  cos_요일        sin_시간  \
# 일시
# 2022-06-01 00:00:00   1   2   0  2022-06-01  0.866025    -0.5  0.000000e+00
# 2022-06-01 01:00:00   1   2   1  2022-06-01  0.866025    -0.5  2.697968e-01
# 2022-06-01 02:00:00   1   2   2  2022-06-01  0.866025    -0.5  5.195840e-01
# 2022-06-01 03:00:00   1   2   3  2022-06-01  0.866025    -0.5  7.308360e-01
# 2022-06-01 04:00:00   1   2   4  2022-06-01  0.866025    -0.5  8.878852e-01
# ...                  ..  ..  ..         ...       ...     ...           ...
# 2022-08-24 19:00:00  24   2  19  2022-08-24  0.866025    -0.5 -8.878852e-01
# 2022-08-24 20:00:00  24   2  20  2022-08-24  0.866025    -0.5 -7.308360e-01
# 2022-08-24 21:00:00  24   2  21  2022-08-24  0.866025    -0.5 -5.195840e-01
# 2022-08-24 22:00:00  24   2  22  2022-08-24  0.866025    -0.5 -2.697968e-01
# 2022-08-24 23:00:00  24   2  23  2022-08-24  0.866025    -0.5 -2.449294e-16
#
#                        cos_시간   일수  휴일  6  7  8
# 일시
# 2022-06-01 00:00:00  1.000000  152   0  1  0  0
# 2022-06-01 01:00:00  0.962917  152   0  1  0  0
# 2022-06-01 02:00:00  0.854419  152   0  1  0  0
# 2022-06-01 03:00:00  0.682553  152   0  1  0  0
# 2022-06-01 04:00:00  0.460065  152   0  1  0  0
# ...                       ...  ...  .. .. .. ..
# 2022-08-24 19:00:00  0.460065  236   0  0  0  1
# 2022-08-24 20:00:00  0.682553  236   0  0  0  1
# 2022-08-24 21:00:00  0.854419  236   0  0  0  1
# 2022-08-24 22:00:00  0.962917  236   0  0  0  1
# 2022-08-24 23:00:00  1.000000  236   0  0  0  1
#
# [204000 rows x 20 columns]

# %%
train_df['풍속'] = train_df['풍속'].interpolate(method = 'time')

# %%
train_df['습도'] = train_df['습도'].interpolate(method = 'time')

# %%
train_df['강수량'] = train_df['강수량'].interpolate(method = 'time')

# %%
train_df = train_df.fillna(0)

# %%
train_df.reset_index(drop = True, inplace = True)

# %%
# cat_month = pd.get_dummies(train_df['월'])
# train_df = pd.concat([train_df, cat_month], axis = 1).drop(columns = ['월'])

# %%
# 건물별, 요일별, 시간별 발전량 평균 넣어주기
# weekday_mean = pd.pivot_table(train_df, values = '전력소비량', index = ['건물번호', '시간', '요일'], aggfunc = np.mean).reset_index()
# tqdm.pandas()
# train_df['요일별_평균'] = train_df.progress_apply(lambda x : weekday_mean.loc[(weekday_mean.건물번호 == x['건물번호']) & (weekday_mean.시간 == x['시간']) & (weekday_mean.요일 == x['요일']), '전력소비량'].values[0], axis = 1)

# %%
# 건물별 시간, 요일별 발전량 표준편차 넣어주기
# weekday_std = pd.pivot_table(train_df, values = '전력소비량', index = ['건물번호', '시간', '요일'], aggfunc = np.std).reset_index()
# tqdm.pandas()
# train_df['요일별_표준편차'] = train_df.progress_apply(lambda x : weekday_std.loc[(weekday_std.건물번호 == x['건물번호']) & (weekday_std.시간 == x['시간']) & (weekday_std.요일 == x['요일']) ,'전력소비량'].values[0], axis = 1)

# %%
# 건물별 시간별 발전량 평균 넣어주기
hour_mean = pd.pivot_table(train_df, values = '전력소비량', index = ['건물번호', '시간'], aggfunc = np.mean).reset_index()
tqdm.pandas()
train_df['시간별_평균'] = train_df.progress_apply(lambda x : hour_mean.loc[(hour_mean.건물번호 == x['건물번호']) & (hour_mean.시간 == x['시간']) ,'전력소비량'].values[0], axis = 1)
# Out:
# 100%|██████████| 204000/204000 [00:56<00:00, 3627.28it/s]

# %%
# 건물별 시간별 발전량 표준편차 넣어주기
hour_std = pd.pivot_table(train_df, values = '전력소비량', index = ['건물번호', '시간'], aggfunc = np.std).reset_index()
tqdm.pandas()
train_df['시간별_표준편차'] = train_df.progress_apply(lambda x : hour_std.loc[(hour_std.건물번호 == x['건물번호']) & (hour_std.시간 == x['시간']) ,'전력소비량'].values[0], axis = 1)
# Out:
# 100%|██████████| 204000/204000 [00:59<00:00, 3447.45it/s]

# %%
# 파생변수 생성 - 열지수
train_df['기온(F)'] = (train_df['기온'] * 9/5) + 32
T = train_df['기온(F)']
RH = train_df['습도']
train_df['열지수'] = -42.379 + 2.04901523*T + 10.14333127*RH - .22475541*T*RH - .00683783*T*T - .05481717*RH*RH + .00122874*T*T*RH + .00085282*T*RH*RH - .00000199*T*T*RH*RH
# train_df['열지수'] = pd.cut(train_df['열지수'], bins = [0, 80, 90, 103, 124, 200], labels = [0, 1, 2, 3, 4])

# %%
plt.hist(train_df['열지수'])
# Out:
# (array([8.1180e+03, 3.3823e+04, 6.7477e+04, 5.3501e+04, 3.0467e+04,
#         9.6840e+03, 9.0200e+02, 2.6000e+01, 0.0000e+00, 2.0000e+00]),
#  array([ 55.63234398,  64.33648518,  73.04062638,  81.74476757,
#          90.44890877,  99.15304997, 107.85719117, 116.56133236,
#         125.26547356, 133.96961476, 142.67375595]),
#  <BarContainer object of 10 artists>)

# %%
# 파생변수 생성 - 체감온도
T = train_df['기온']
W = train_df['풍속']
train_df['체감온도'] = 13.12 + 0.6215*T - 11.37*(W)**0.16 + 0.3965*(W)**0.16*T

# %%
plt.hist(train_df['체감온도'])
# Out:
# (array([   87.,  1681.,  8468., 13567., 36719., 62772., 50259., 23416.,
#          6608.,   423.]),
#  array([11.66635676, 14.52956944, 17.39278212, 20.25599479, 23.11920747,
#         25.98242015, 28.84563283, 31.70884551, 34.57205818, 37.43527086,
#         40.29848354]),
#  <BarContainer object of 10 artists>)

# %%
# 파생변수 생성 - 불쾌지수
T = 9/5*train_df['기온']
RH = train_df['습도']
train_df['불쾌지수'] = T - 0.55*(1-RH/100)*(T-26)+32
# train_df['불쾌지수'] = pd.cut(train_df['불쾌지수'], bins = [0, 68, 75, 80, 200], labels = [0, 1, 2, 3])

# %%
plt.hist(train_df['불쾌지수'])
# Out:
# (array([7.9000e+01, 7.4500e+02, 6.1020e+03, 1.3240e+04, 2.1056e+04,
#         5.1848e+04, 6.8968e+04, 3.8384e+04, 3.5760e+03, 2.0000e+00]),
#  array([50.48107 , 54.684915, 58.88876 , 63.092605, 67.29645 , 71.500295,
#         75.70414 , 79.907985, 84.11183 , 88.315675, 92.51952 ]),
#  <BarContainer object of 10 artists>)

# %%
# 파생변수 생성 - CDH
def CDH(x):
    y = []
    for i in range(len(x)):
        if i<11:
            y.append(np.sum(x[:(i+1)]-26))
        else:
            y.append(np.sum(x[(i-11):(i+1)]-26))
    return np.array(x)

# %%
cdhs = np.array([])

for num in range(1, 101):
    temp = train_df[train_df['건물번호'] == num]
    cdh = CDH(temp['기온'].values)
    cdhs = np.concatenate([cdhs, cdh])

train_df['CDH'] = cdhs

# %%
plt.hist(train_df['CDH'])
# Out:
# (array([  113.,  1349.,  8264., 12984., 31299., 62308., 51474., 27437.,
#          8151.,   621.]),
#  array([10.1, 12.8, 15.5, 18.2, 20.9, 23.6, 26.3, 29. , 31.7, 34.4, 37.1]),
#  <BarContainer object of 10 artists>)

# %%
# 이상치 제거 -> 안하는게 나음
def detect_outliers(df,ratio): 
    outlier_indices = [] 
    Q1 = np.percentile(df, 25) 
    Q3 = np.percentile(df, 75) 
    IQR = Q3 - Q1 
    outlier_step = ratio * IQR 
    return ~(df < Q1 - outlier_step) | (df > Q3 + outlier_step)

# for i in range(100):    
#     idx = detect_outliers(train_target[i],1.25)
#     train_target[i] = train_target[i][idx]
#     train_input[i] = train_input[i][idx]

# %%
train_df.columns
# Out:
# Index([    '건물번호',       '일시',       '기온',      '강수량',       '풍속',       '습도',
#           '전력소비량',        '일',       '요일',       '시간',       '날짜',   'sin_요일',
#          'cos_요일',   'sin_시간',   'cos_시간',       '일수',       '휴일',          6,
#                 7,          8,   '시간별_평균', '시간별_표준편차',    '기온(F)',      '열지수',
#            '체감온도',     '불쾌지수',      'CDH'],
#       dtype='object')

# %%
train_df = train_df.drop(columns = ['일시', '일', '날짜',  '요일', '시간', '기온(F)'])

# %%
import matplotlib.gridspec as gridspec 

grid = gridspec.GridSpec(12,2)
fig = plt.figure(figsize = (20, 15))
plt.subplots_adjust(wspace = 0.3, hspace = 0.2)

for idx, feature in enumerate(train_df.columns[1:]):
    ax = plt.subplot(grid[idx])
    plt.hist(train_df[feature])
    plt.title(f"{feature}")
# Out:
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50728 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54413 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49549 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49845 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47141 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 55092 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44512 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54364 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51456 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54200 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50676 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52404 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44048 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48520 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 53132 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50728 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54413 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49549 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49845 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 47141 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49548 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48708 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 55092 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44512 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54364 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51456 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54200 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50676 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52404 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44048 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48520 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 53132 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import matplotlib.gridspec as gridspec 

grid = gridspec.GridSpec(7,1)
fig = plt.figure(figsize = (20, 15))
plt.subplots_adjust(wspace = 0.3, hspace = 0.2)

for idx, feature in enumerate(['풍속', '습도', '전력소비량', '시간별_평균', '시간별_표준편차']):
    ax = plt.subplot(grid[idx])
    plt.hist(train_df[feature])
    plt.title(f"{feature}")

# %%
train_df['log_풍속'] = np.log1p(train_df['풍속'])
train_df['log_전력소비량'] = np.log1p(train_df['전력소비량'])

# train_df['log_요일별_평균'] = np.log1p(train_df['요일별_평균'])
# train_df['log_요일별_표준편차'] = np.log1p(train_df['요일별_표준편차'])
train_df['log_시간별_평균'] = np.log1p(train_df['시간별_평균'])
train_df['log_시간별_표준편차'] = np.log1p(train_df['시간별_표준편차'])

# %%
import matplotlib.gridspec as gridspec 

grid = gridspec.GridSpec(6,1)
fig = plt.figure(figsize = (20, 15))
plt.subplots_adjust(wspace = 0.3, hspace = 0.2)

for idx, feature in enumerate(['log_풍속', 'log_전력소비량', 'log_시간별_평균', 'log_시간별_표준편차']):
    ax = plt.subplot(grid[idx])
    plt.hist(train_df[feature])
    plt.title(f"{feature}")

# %%
train_df
# Out:
#         건물번호    기온  강수량   풍속    습도    전력소비량    sin_요일  cos_요일        sin_시간  \
# 0          1  18.6  0.0  0.9  42.0  1085.28  0.866025    -0.5  0.000000e+00
# 1          1  18.0  0.0  1.1  45.0  1047.36  0.866025    -0.5  2.697968e-01
# 2          1  17.7  0.0  1.5  45.0   974.88  0.866025    -0.5  5.195840e-01
# 3          1  16.7  0.0  1.4  48.0   953.76  0.866025    -0.5  7.308360e-01
# 4          1  18.4  0.0  2.8  43.0   986.40  0.866025    -0.5  8.878852e-01
# ...      ...   ...  ...  ...   ...      ...       ...     ...           ...
# 203995   100  23.1  0.0  0.9  86.0   881.04  0.866025    -0.5 -8.878852e-01
# 203996   100  22.4  0.0  1.3  86.0   798.96  0.866025    -0.5 -7.308360e-01
# 203997   100  21.3  0.0  1.0  92.0   825.12  0.866025    -0.5 -5.195840e-01
# 203998   100  21.0  0.0  0.3  94.0   640.08  0.866025    -0.5 -2.697968e-01
# 203999   100  20.7  0.0  0.1  95.0   540.24  0.866025    -0.5 -2.449294e-16
#
#           cos_시간  ...       시간별_평균    시간별_표준편차        열지수       체감온도  \
# 0       1.000000  ...  1706.318118  446.882767  78.408916  20.751584
# 1       0.962917  ...  1622.620235  439.662704  79.147251  20.008954
# 2       0.854419  ...  1506.971294  412.071906  79.492837  19.476910
# 3       0.682553  ...  1437.365647  391.205981  80.948219  18.487958
# 4       0.460065  ...  1447.321412  381.099697  78.649811  19.751534
# ...          ...  ...          ...         ...        ...        ...
# 203995  0.460065  ...  1010.462118  161.399578  72.567800  25.302757
# 203996  0.682553  ...   928.125176  137.566008  70.929804  24.446518
# 203997  0.854419  ...   830.032941  128.300189  66.382661  23.433400
# 203998  0.962917  ...   723.100235  112.464079  64.810657  23.661275
# 203999  1.000000  ...   588.784941   91.484424  63.674052  23.797169
#
#             불쾌지수   CDH    log_풍속  log_전력소비량  log_시간별_평균  log_시간별_표준편차
# 0       63.09388  18.6  0.641854   6.990514    7.442679      6.104532
# 1       62.46400  18.0  0.741937   6.954982    7.392414      6.088280
# 2       62.08735  17.7  0.916291   6.883340    7.318521      6.023622
# 3       60.89884  16.7  0.875469   6.861460    7.271263      5.971787
# 4       62.88788  18.4  1.335001   6.895075    7.278161      5.945682
# ...          ...   ...       ...        ...         ...           ...
# 203995  72.38034  23.1  0.641854   6.782237    6.919152      5.090060
# 203996  71.21736  22.4  0.832909   6.684562    6.834243      4.931347
# 203997  69.79704  21.3  0.693147   6.716740    6.722669      4.862137
# 203998  69.41060  21.0  0.262364   6.463154    6.584930      4.731486
# 203999  68.95035  20.7  0.095310   6.293863    6.379758      4.527040
#
# [204000 rows x 25 columns]

# %%
plt.plot(train_df[['log_전력소비량']])
# plt.plot(train_df[['log_요일별_평균']])
plt.plot(train_df[['log_시간별_평균']])

# %%
train_df.columns
# Out:
# Index([        '건물번호',           '기온',          '강수량',           '풍속',
#                  '습도',        '전력소비량',       'sin_요일',       'cos_요일',
#              'sin_시간',       'cos_시간',           '일수',           '휴일',
#                     6,              7,              8,       '시간별_평균',
#            '시간별_표준편차',          '열지수',         '체감온도',         '불쾌지수',
#                 'CDH',       'log_풍속',    'log_전력소비량',   'log_시간별_평균',
#        'log_시간별_표준편차'],
#       dtype='object')

# %%
train_df = train_df[['건물번호', 'log_전력소비량', '기온', '강수량', '습도', 'sin_요일', 'cos_요일',
       'sin_시간', 'cos_시간', '일수', '휴일', '열지수', '체감온도', '불쾌지수', 'CDH', 'log_풍속',
       'log_시간별_평균', 'log_시간별_표준편차', 6, 7, 8]]
train_dfs  = []
for i in range(1,101):
    train_dfs.append(train_df[train_df['건물번호']==i])

# %%
for i in range(100):
    train_dfs[i] = train_dfs[i].drop(columns = ['건물번호'])

# %%
train_input = [] 
train_target = []

for i in range(len(train_dfs)):
    train_input.append(copy.deepcopy(train_dfs[i][train_dfs[i].columns[1:]])) 
    train_target.append(copy.deepcopy(train_dfs[i][train_dfs[i].columns[0]]))

# %%
test
# Out:
#          num_date_time  건물번호           일시  기온(C)  강수량(mm)  풍속(m/s)  습도(%)
# 0        1_20220825 00     1  20220825 00   23.5      0.0      2.2     72
# 1        1_20220825 01     1  20220825 01   23.0      0.0      0.9     72
# 2        1_20220825 02     1  20220825 02   22.7      0.0      1.5     75
# 3        1_20220825 03     1  20220825 03   22.1      0.0      1.3     78
# 4        1_20220825 04     1  20220825 04   21.8      0.0      1.0     77
# ...                ...   ...          ...    ...      ...      ...    ...
# 16795  100_20220831 19   100  20220831 19   22.5      0.0      0.9     84
# 16796  100_20220831 20   100  20220831 20   20.7      0.0      0.4     95
# 16797  100_20220831 21   100  20220831 21   20.2      0.0      0.4     98
# 16798  100_20220831 22   100  20220831 22   20.1      0.0      1.1     97
# 16799  100_20220831 23   100  20220831 23   19.1      0.0      0.1     99
#
# [16800 rows x 7 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16800 entries, 0 to 16799
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   num_date_time  16800 non-null  object
#  1   건물번호           16800 non-null  int64
#  2   일시             16800 non-null  object
#  3   기온(C)          16800 non-null  float64
#  4   강수량(mm)        16800 non-null  float64
#  5   풍속(m/s)        16800 non-null  float64
#  6   습도(%)          16800 non-null  int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 918.9+ KB

# %%
test_df = test.copy()

test_df = test_df.drop(columns =  ['num_date_time'])
test_df = test_df.rename(columns = {'기온(C)':'기온', '강수량(mm)':'강수량', '풍속(m/s)':'풍속', '습도(%)':'습도'})

## 일시 columns
test_df['일시'] = pd.to_datetime(test_df['일시'])
test_df['월'] = test_df['일시'].dt.month
test_df['일'] = test_df['일시'].dt.day
test_df['요일'] = test_df['일시'].dt.weekday
test_df['시간'] = test_df['일시'].dt.hour
# test_df['날짜'] = test_df['일시'].dt.date

test_df['sin_요일'] = np.sin(2*np.pi*(test_df['요일'])/6)
test_df['cos_요일'] = np.cos(2*np.pi*(test_df['요일'])/6)
test_df['sin_시간'] = np.sin(2*np.pi*(test_df['시간'])/23)
test_df['cos_시간'] = np.cos(2*np.pi*(test_df['시간'])/23)
# test_df['sin_일'] = np.sin(2*np.pi*(test_df['일']-1)/30)
# test_df['cos_일'] = np.cos(2*np.pi*(test_df['일']-1)/30)
test_df['일수'] = test_df['일시'].dt.dayofyear

test_df['휴일'] = test_df['요일'].isin([5,6]).astype(int)

# 파생변수 생성 - 열지수
test_df['기온(F)'] = (test_df['기온'] * 9/5) + 32
T = test_df['기온(F)']
RH = test_df['습도']
test_df['열지수'] = -42.379 + 2.04901523*T + 10.14333127*RH - .22475541*T*RH - .00683783*T*T - .05481717*RH*RH + .00122874*T*T*RH + .00085282*T*RH*RH - .00000199*T*T*RH*RH
# test_df['열지수'] = pd.cut(test_df['열지수'], bins = [0, 80, 90, 103, 124, 200], labels = [0, 1, 2, 3, 4])

# 파생변수 생성 - 체감온도
T = test_df['기온']
W = test_df['풍속']
test_df['체감온도'] = 13.12 + 0.6215*T - 11.37*(W)**0.16 + 0.3965*(W)**0.16*T

# 파생변수 생성 - 불쾌지수
T = 9/5*test_df['기온']
RH = test_df['습도']
test_df['불쾌지수'] = T - 0.55*(1-RH/100)*(T-26)+32
# test_df['불쾌지수'] = pd.cut(test_df['불쾌지수'], bins = [0, 68, 75, 80, 200], labels = [0, 1, 2, 3])

# 파생변수 생성 - CDH

cdhs = np.array([])
for num in range(1, 101):
    temp = test_df[test_df['건물번호'] == num]
    cdh = CDH(temp['기온'].values)
    cdhs = np.concatenate([cdhs, cdh])

test_df['CDH'] = cdhs

test_df['log_풍속'] = np.log1p(test_df['풍속'])

# 전력소비량 넣어주기
# test_df['요일별_평균'] = test_df.progress_apply(lambda x : weekday_mean.loc[(weekday_mean.건물번호 == x['건물번호']) & (weekday_mean.시간 == x['시간']) & (weekday_mean.요일 == x['요일']), '전력소비량'].values[0], axis = 1)
# test_df['요일별_표준편차'] = test_df.progress_apply(lambda x : weekday_std.loc[(weekday_std.건물번호 == x['건물번호']) & (weekday_std.시간 == x['시간']) & (weekday_std.요일 == x['요일']) ,'전력소비량'].values[0], axis = 1)
test_df['시간별_평균'] = test_df.progress_apply(lambda x : hour_mean.loc[(hour_mean.건물번호 == x['건물번호']) & (hour_mean.시간 == x['시간']) ,'전력소비량'].values[0], axis = 1)
test_df['시간별_표준편차'] = test_df.progress_apply(lambda x : hour_std.loc[(hour_std.건물번호 == x['건물번호']) & (hour_std.시간 == x['시간']) ,'전력소비량'].values[0], axis = 1)

# test_df['log_요일별_평균'] = np.log1p(test_df['요일별_평균'])
# test_df['log_요일별_표준편차'] = np.log1p(test_df['요일별_표준편차'])
test_df['log_시간별_평균'] = np.log1p(test_df['시간별_평균'])
test_df['log_시간별_표준편차'] = np.log1p(test_df['시간별_표준편차'])

test_df[6] = 0
test_df[7] = 0
cat_month = pd.get_dummies(test_df['월'])
test_df = pd.concat([test_df, cat_month], axis = 1).drop(columns = ['월'])
# Out:
# 100%|██████████| 16800/16800 [00:04<00:00, 3497.64it/s]
# 100%|██████████| 16800/16800 [00:04<00:00, 3655.70it/s]

# %%
test_df[6] = test_df[6].astype('uint8')
test_df[7] = test_df[7].astype('uint8')

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16800 entries, 0 to 16799
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   건물번호          16800 non-null  int64
#  1   일시            16800 non-null  datetime64[ns]
#  2   기온            16800 non-null  float64
#  3   강수량           16800 non-null  float64
#  4   풍속            16800 non-null  float64
#  5   습도            16800 non-null  int64
#  6   일             16800 non-null  int64
#  7   요일            16800 non-null  int64
#  8   시간            16800 non-null  int64
#  9   sin_요일        16800 non-null  float64
#  10  cos_요일        16800 non-null  float64
#  11  sin_시간        16800 non-null  float64
#  12  cos_시간        16800 non-null  float64
#  13  일수            16800 non-null  int64
#  14  휴일            16800 non-null  int32
#  15  기온(F)         16800 non-null  float64
#  16  열지수           16800 non-null  float64
#  17  체감온도          16800 non-null  float64
#  18  불쾌지수          16800 non-null  float64
#  19  CDH           16800 non-null  float64
#  20  log_풍속        16800 non-null  float64
#  21  시간별_평균        16800 non-null  float64
#  22  시간별_표준편차      16800 non-null  float64
#  23  log_시간별_평균    16800 non-null  float64
#  24  log_시간별_표준편차  16800 non-null  float64
#  25  6             16800 non-null  uint8
#  26  7             16800 non-null  uint8
#  27  8             16800 non-null  uint8
# dtypes: datetime64[ns](1), float64(17), int32(1), int64(6), uint8(3)
# memory usage: 3.2 MB

# %%
test_df = test_df[['건물번호', '기온', '강수량', '습도','sin_요일', 'cos_요일',
       'sin_시간', 'cos_시간', '일수', '휴일', '열지수', '체감온도', '불쾌지수', 'CDH', 'log_풍속',
       'log_시간별_평균', 'log_시간별_표준편차', 6, 7, 8]]
test_input  = []
for i in range(1,101):
    test_input.append(test_df[test_df['건물번호']==i])

for i in range(100):
    test_input[i] = test_input[i].drop(columns = ['건물번호'])

# %%
import matplotlib.gridspec as gridspec 

grid = gridspec.GridSpec(12,2)
fig = plt.figure(figsize = (20, 15))
plt.subplots_adjust(wspace = 0.3, hspace = 0.2)

for idx, feature in enumerate(test_df.columns):
    ax = plt.subplot(grid[idx])
    plt.hist(test_df[feature])
    plt.title(f"{feature}")
# Out:
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44148 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47932 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48264 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54840 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50728 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49845 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 55092 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50676 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52404 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44048 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48520 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 53132 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54413 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49549 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44512 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54364 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51456 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54200 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44148 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 47932 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48264 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54840 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50728 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49845 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44036 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 55092 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 50676 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52404 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44048 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48520 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 53132 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54413 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49549 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44512 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54364 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51456 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54200 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
display(train_input[0])
display(test_input[0])
# Out:
#         기온  강수량    습도    sin_요일  cos_요일        sin_시간    cos_시간   일수  휴일  \
# 0     18.6  0.0  42.0  0.866025    -0.5  0.000000e+00  1.000000  152   0
# 1     18.0  0.0  45.0  0.866025    -0.5  2.697968e-01  0.962917  152   0
# 2     17.7  0.0  45.0  0.866025    -0.5  5.195840e-01  0.854419  152   0
# 3     16.7  0.0  48.0  0.866025    -0.5  7.308360e-01  0.682553  152   0
# 4     18.4  0.0  43.0  0.866025    -0.5  8.878852e-01  0.460065  152   0
# ...    ...  ...   ...       ...     ...           ...       ...  ...  ..
# 2035  25.5  0.0  63.0  0.866025    -0.5 -8.878852e-01  0.460065  236   0
# 2036  25.0  0.0  66.0  0.866025    -0.5 -7.308360e-01  0.682553  236   0
# 2037  24.6  0.0  67.0  0.866025    -0.5 -5.195840e-01  0.854419  236   0
# 2038  24.1  0.0  70.0  0.866025    -0.5 -2.697968e-01  0.962917  236   0
# 2039  23.8  0.0  70.0  0.866025    -0.5 -2.449294e-16  1.000000  236   0
#
#             열지수       체감온도      불쾌지수   CDH    log_풍속  log_시간별_평균  \
# 0     78.408916  20.751584  63.09388  18.6  0.641854    7.442679
# 1     79.147251  20.008954  62.46400  18.0  0.741937    7.392414
# 2     79.492837  19.476910  62.08735  17.7  0.916291    7.318521
# 3     80.948219  18.487958  60.89884  16.7  0.875469    7.271263
# 4     78.649811  19.751534  62.88788  18.4  1.335001    7.278161
# ...         ...        ...       ...   ...       ...         ...
# 2035  79.681361  27.475127  73.85035  25.5  1.360977    7.902810
# 2036  78.797002  26.959240  73.44700  25.0  1.280934    7.821234
# 2037  78.058634  26.723515  72.96218  24.6  0.832909    7.587466
# 2038  77.031069  26.055113  72.51230  24.1  1.131402    7.295769
# 2039  76.532285  25.871467  72.06140  23.8  0.875469    7.476518
#
#       log_시간별_표준편차  6  7  8
# 0         6.104532  1  0  0
# 1         6.088280  1  0  0
# 2         6.023622  1  0  0
# 3         5.971787  1  0  0
# 4         5.945682  1  0  0
# ...            ... .. .. ..
# 2035      5.936241  0  0  1
# 2036      5.879386  0  0  1
# 2037      5.383027  0  0  1
# 2038      4.753586  0  0  1
# 2039      6.055320  0  0  1
#
# [2040 rows x 19 columns]
#        기온  강수량  습도        sin_요일  cos_요일        sin_시간    cos_시간   일수  휴일  \
# 0    23.5  0.0  72  1.224647e-16    -1.0  0.000000e+00  1.000000  237   0
# 1    23.0  0.0  72  1.224647e-16    -1.0  2.697968e-01  0.962917  237   0
# 2    22.7  0.0  75  1.224647e-16    -1.0  5.195840e-01  0.854419  237   0
# 3    22.1  0.0  78  1.224647e-16    -1.0  7.308360e-01  0.682553  237   0
# 4    21.8  0.0  77  1.224647e-16    -1.0  8.878852e-01  0.460065  237   0
# ..    ...  ...  ..           ...     ...           ...       ...  ...  ..
# 163  23.5  0.0  75  8.660254e-01    -0.5 -8.878852e-01  0.460065  243   0
# 164  22.4  0.0  80  8.660254e-01    -0.5 -7.308360e-01  0.682553  243   0
# 165  21.7  0.0  81  8.660254e-01    -0.5 -5.195840e-01  0.854419  243   0
# 166  21.1  0.0  83  8.660254e-01    -0.5 -2.697968e-01  0.962917  243   0
# 167  20.8  0.0  87  8.660254e-01    -0.5 -2.449294e-16  1.000000  243   0
#
#            열지수       체감온도      불쾌지수   CDH    log_풍속  log_시간별_평균  log_시간별_표준편차  \
# 0    75.835980  25.397063  71.78980  23.5  1.163151    7.442679      6.104532
# 1    75.097159  25.201620  71.02840  23.0  0.641854    7.392414      6.088280
# 2    74.149922  24.699788  70.81675  22.7  0.916291    7.318521      6.023622
# 3    72.636805  24.136018  70.11262  22.1  0.832909    7.271263      5.971787
# 4    72.533716  23.942400  69.56514  21.8  0.693147    7.278161      5.945682
# ..         ...        ...       ...   ...       ...         ...           ...
# 163  75.442391  25.432297  72.05875  23.5  1.098612    7.902810      5.936241
# 164  72.571571  24.261343  70.74480  22.4  1.098612    7.821234      5.879386
# 165  71.235792  23.624578  69.69523  21.7  0.955511    7.587466      5.383027
# 166  69.774703  23.229800  68.85987  21.1  0.693147    7.295769      4.753586
# 167  67.751552  23.097622  68.62204  20.8  0.530628    7.476518      6.055320
#
#      6  7  8
# 0    0  0  1
# 1    0  0  1
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 163  0  0  1
# 164  0  0  1
# 165  0  0  1
# 166  0  0  1
# 167  0  0  1
#
# [168 rows x 19 columns]

# %%
submission = pd.read_csv('../dataset/sample_submission.csv')

# %%
random_seed = 42
K = [i for i in [5]]
# catfeatures = ['월', '휴일', '불쾌지수', '열지수']

# cat_mae_params = {
#     'objective': 'MAE',
#     'n_estimators': 10000,
#     'early_stopping_rounds': 4, 
#     'cat_features' : catfeatures,
#     'one_hot_max_size' : 5
# } # catboost hyper parameter

# lgbm_mae_params = {
#     'objective': 'MAE',
#     'boosting_type': 'goss',
#     'n_estimators': 10000,
#     'early_stopping_round': 15, 
#     'num_leaves':39,
#     'categorical_feature = name' : catfeatures
# } # lightgbm hyper parameter

xgboost_params = {
    'objective':'reg:linear',
    'eval_metric' : 'rmse',
    'n_estimators':1000,
    'seed':random_seed,
    'min_child_weight':1,
    'eta':0.3,
    'gamma':0,
    'max_depth':6,
    'sub_sample':1,
    'colsample_bytree' : 1,
    'lambda':1,
    'alpha':0,
    'scale_pos_weight':1
}

for k in K: # kfold 의 nspilt 의 값 k
    folds = []
    for i in range(len(train_dfs)):
        cross = KFold(n_splits = k, shuffle = True, random_state = random_seed)
        fold = []
        for train_idx, valid_idx in cross.split(train_input[i], train_target[i]):
            fold.append((train_idx, valid_idx))
        folds.append(fold)
            
    for i in range(len(train_dfs)):
        for fold in range(k):
            print(random_seed, k, i)
            train_idx, valid_idx = folds[i][fold]
            X_train = train_input[i].iloc[train_idx]
            y_train = train_target[i].iloc[train_idx]
            X_valid = train_input[i].iloc[valid_idx]
            y_valid = train_target[i].iloc[valid_idx]                
            # catboost 학습 
            # model = CatBoostRegressor(**cat_mae_params)
            # model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)])
            # v = (np.exp(model.predict(test_input[i][train_input[i].columns]))-1) * 1
                
            #lgbm 학습 
            # model=LGBMRegressor(**lgbm_mae_params)
            # model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)])        
            # v = (np.exp(model.predict(test_input[i][train_input[i].columns]))-1) * 1
            
            # xgboost 학습
            model = XGBRegressor(**xgboost_params)
            model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)])
            v = (np.exp(model.predict(test_input[i][train_input[i].columns]))-1) * 1
    
            submission['answer'].iloc[(i)*168:(i+1)*168] += v/(len(K)*k)
            clear_output(True)
# Out:
# 42 5 99
# [15:47:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [15:47:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\learner.cc:767:
# Parameters: { "sub_sample" } are not used.
#
# [0]	validation_0-rmse:4.31910
# [1]	validation_0-rmse:3.03172
# [2]	validation_0-rmse:2.12534
# [3]	validation_0-rmse:1.49241
# [4]	validation_0-rmse:1.05062
# [5]	validation_0-rmse:0.74070
# [6]	validation_0-rmse:0.52482
# [7]	validation_0-rmse:0.37505
# [8]	validation_0-rmse:0.27092
# [9]	validation_0-rmse:0.19970
# [10]	validation_0-rmse:0.15327
# [11]	validation_0-rmse:0.12093
# [12]	validation_0-rmse:0.10222
# [13]	validation_0-rmse:0.09093
# [14]	validation_0-rmse:0.08383
# [15]	validation_0-rmse:0.08057
# [16]	validation_0-rmse:0.07880
# [17]	validation_0-rmse:0.07790
# [18]	validation_0-rmse:0.07686
# [19]	validation_0-rmse:0.07631
# [20]	validation_0-rmse:0.07579
# [21]	validation_0-rmse:0.07560
# [22]	validation_0-rmse:0.07512
# [23]	validation_0-rmse:0.07520
# [24]	validation_0-rmse:0.07492
# [25]	validation_0-rmse:0.07461
# [26]	validation_0-rmse:0.07331
# [27]	validation_0-rmse:0.07322
# [28]	validation_0-rmse:0.07314
# [29]	validation_0-rmse:0.07314
# [30]	validation_0-rmse:0.07305
# [31]	validation_0-rmse:0.07312
# [32]	validation_0-rmse:0.07298
# [33]	validation_0-rmse:0.07296
# [34]	validation_0-rmse:0.07278
# [35]	validation_0-rmse:0.07292
# [36]	validation_0-rmse:0.07277
# [37]	validation_0-rmse:0.07271
# [38]	validation_0-rmse:0.07273
# [39]	validation_0-rmse:0.07262
# [40]	validation_0-rmse:0.07273
# [41]	validation_0-rmse:0.07269
# [42]	validation_0-rmse:0.07259
# [43]	validation_0-rmse:0.07258
# [44]	validation_0-rmse:0.07248
# [45]	validation_0-rmse:0.07247
# [46]	validation_0-rmse:0.07242
# [47]	validation_0-rmse:0.07256
# [48]	validation_0-rmse:0.07239
# [49]	validation_0-rmse:0.07243
# [50]	validation_0-rmse:0.07238
# [51]	validation_0-rmse:0.07238
# [52]	validation_0-rmse:0.07245
# [53]	validation_0-rmse:0.07254
# [54]	validation_0-rmse:0.07278
# [55]	validation_0-rmse:0.07281
# [56]	validation_0-rmse:0.07279
# [57]	validation_0-rmse:0.07290
# [58]	validation_0-rmse:0.07287
# [59]	validation_0-rmse:0.07283
# [60]	validation_0-rmse:0.07290
# [61]	validation_0-rmse:0.07266
# [62]	validation_0-rmse:0.07267
# [63]	validation_0-rmse:0.07277
# [64]	validation_0-rmse:0.07276
# [65]	validation_0-rmse:0.07276
# [66]	validation_0-rmse:0.07276
# [67]	validation_0-rmse:0.07272
# [68]	validation_0-rmse:0.07268
# [69]	validation_0-rmse:0.07256
# [70]	validation_0-rmse:0.07256
# [71]	validation_0-rmse:0.07256
# [72]	validation_0-rmse:0.07260
# [73]	validation_0-rmse:0.07265
# [74]	validation_0-rmse:0.07265
# [75]	validation_0-rmse:0.07265
# [76]	validation_0-rmse:0.07265
# [77]	validation_0-rmse:0.07262
# [78]	validation_0-rmse:0.07267
# [79]	validation_0-rmse:0.07275
# [80]	validation_0-rmse:0.07271
# [81]	validation_0-rmse:0.07261
# [82]	validation_0-rmse:0.07269
# [83]	validation_0-rmse:0.07268
# [84]	validation_0-rmse:0.07269
# [85]	validation_0-rmse:0.07270
# [86]	validation_0-rmse:0.07267
# [87]	validation_0-rmse:0.07266
# [88]	validation_0-rmse:0.07272
# [89]	validation_0-rmse:0.07273
# [90]	validation_0-rmse:0.07272
# [91]	validation_0-rmse:0.07270
# [92]	validation_0-rmse:0.07270
# [93]	validation_0-rmse:0.07268
# [94]	validation_0-rmse:0.07265
# [95]	validation_0-rmse:0.07269
# [96]	validation_0-rmse:0.07268
# [97]	validation_0-rmse:0.07273
# [98]	validation_0-rmse:0.07271
# [99]	validation_0-rmse:0.07274
# [100]	validation_0-rmse:0.07266
# [101]	validation_0-rmse:0.07262
# [102]	validation_0-rmse:0.07258
# [103]	validation_0-rmse:0.07262
# [104]	validation_0-rmse:0.07263
# [105]	validation_0-rmse:0.07264
# [106]	validation_0-rmse:0.07257
# [107]	validation_0-rmse:0.07258
# [108]	validation_0-rmse:0.07261
# [109]	validation_0-rmse:0.07258
# [110]	validation_0-rmse:0.07258
# [111]	validation_0-rmse:0.07257
# [112]	validation_0-rmse:0.07258
# [113]	validation_0-rmse:0.07260
# [114]	validation_0-rmse:0.07260
# [115]	validation_0-rmse:0.07265
# [116]	validation_0-rmse:0.07266
# [117]	validation_0-rmse:0.07268
# [118]	validation_0-rmse:0.07265
# [119]	validation_0-rmse:0.07266
# [120]	validation_0-rmse:0.07265
# [121]	validation_0-rmse:0.07265
# [122]	validation_0-rmse:0.07263
# [123]	validation_0-rmse:0.07264
# [124]	validation_0-rmse:0.07264
# [125]	validation_0-rmse:0.07264
# [126]	validation_0-rmse:0.07265
# [127]	validation_0-rmse:0.07264
# [128]	validation_0-rmse:0.07262
# [129]	validation_0-rmse:0.07264
# [130]	validation_0-rmse:0.07265
# [131]	validation_0-rmse:0.07264
# [132]	validation_0-rmse:0.07263
# [133]	validation_0-rmse:0.07264
# [134]	validation_0-rmse:0.07261
# [135]	validation_0-rmse:0.07262
# [136]	validation_0-rmse:0.07260
# [137]	validation_0-rmse:0.07262
# [138]	validation_0-rmse:0.07264
# [139]	validation_0-rmse:0.07263
# [140]	validation_0-rmse:0.07265
# [141]	validation_0-rmse:0.07265
# [142]	validation_0-rmse:0.07266
# [143]	validation_0-rmse:0.07268
# [144]	validation_0-rmse:0.07267
# [145]	validation_0-rmse:0.07266
# [146]	validation_0-rmse:0.07266
# [147]	validation_0-rmse:0.07264
# [148]	validation_0-rmse:0.07262
# [149]	validation_0-rmse:0.07262
# [150]	validation_0-rmse:0.07262
# [151]	validation_0-rmse:0.07260
# [152]	validation_0-rmse:0.07261
# [153]	validation_0-rmse:0.07261
# [154]	validation_0-rmse:0.07262
# [155]	validation_0-rmse:0.07262
# [156]	validation_0-rmse:0.07261
# [157]	validation_0-rmse:0.07260
# [158]	validation_0-rmse:0.07260
# [159]	validation_0-rmse:0.07261
# [160]	validation_0-rmse:0.07260
# [161]	validation_0-rmse:0.07260
# [162]	validation_0-rmse:0.07261
# [163]	validation_0-rmse:0.07261
# [164]	validation_0-rmse:0.07259
# [165]	validation_0-rmse:0.07259
# [166]	validation_0-rmse:0.07259
# [167]	validation_0-rmse:0.07259
# [168]	validation_0-rmse:0.07258
# [169]	validation_0-rmse:0.07258
# [170]	validation_0-rmse:0.07257
# [171]	validation_0-rmse:0.07257
# [172]	validation_0-rmse:0.07258
# [173]	validation_0-rmse:0.07258
# [174]	validation_0-rmse:0.07256
# [175]	validation_0-rmse:0.07255
# [176]	validation_0-rmse:0.07255
# [177]	validation_0-rmse:0.07256
# [178]	validation_0-rmse:0.07256
# [179]	validation_0-rmse:0.07256
# [180]	validation_0-rmse:0.07255
# [181]	validation_0-rmse:0.07255
# [182]	validation_0-rmse:0.07254
# [183]	validation_0-rmse:0.07255
# [184]	validation_0-rmse:0.07255
# [185]	validation_0-rmse:0.07255
# [186]	validation_0-rmse:0.07255
# [187]	validation_0-rmse:0.07255
# [188]	validation_0-rmse:0.07255
# [189]	validation_0-rmse:0.07255
# [190]	validation_0-rmse:0.07256
# [191]	validation_0-rmse:0.07256
# [192]	validation_0-rmse:0.07256
# [193]	validation_0-rmse:0.07255
# [194]	validation_0-rmse:0.07254
# [195]	validation_0-rmse:0.07254
# [196]	validation_0-rmse:0.07254
# [197]	validation_0-rmse:0.07254
# [198]	validation_0-rmse:0.07254
# [199]	validation_0-rmse:0.07254
# [200]	validation_0-rmse:0.07254
# [201]	validation_0-rmse:0.07254
# [202]	validation_0-rmse:0.07254
# [203]	validation_0-rmse:0.07254
# [204]	validation_0-rmse:0.07254
# [205]	validation_0-rmse:0.07254
# [206]	validation_0-rmse:0.07254
# [207]	validation_0-rmse:0.07254
# [208]	validation_0-rmse:0.07254
# [209]	validation_0-rmse:0.07254
# [210]	validation_0-rmse:0.07254
# [211]	validation_0-rmse:0.07254
# [212]	validation_0-rmse:0.07254
# [213]	validation_0-rmse:0.07254
# [214]	validation_0-rmse:0.07254
# [215]	validation_0-rmse:0.07254
# [216]	validation_0-rmse:0.07254
# [217]	validation_0-rmse:0.07254
# [218]	validation_0-rmse:0.07254
# [219]	validation_0-rmse:0.07254
# [220]	validation_0-rmse:0.07254
# [221]	validation_0-rmse:0.07254
# [222]	validation_0-rmse:0.07254
# [223]	validation_0-rmse:0.07254
# [224]	validation_0-rmse:0.07254
# [225]	validation_0-rmse:0.07254
# [226]	validation_0-rmse:0.07254
# [227]	validation_0-rmse:0.07254
# [228]	validation_0-rmse:0.07254
# [229]	validation_0-rmse:0.07254
# [230]	validation_0-rmse:0.07254
# [231]	validation_0-rmse:0.07254
# [232]	validation_0-rmse:0.07254
# [233]	validation_0-rmse:0.07254
# [234]	validation_0-rmse:0.07254
# [235]	validation_0-rmse:0.07254
# [236]	validation_0-rmse:0.07254
# [237]	validation_0-rmse:0.07254
# [238]	validation_0-rmse:0.07254
# [239]	validation_0-rmse:0.07254
# [240]	validation_0-rmse:0.07254
# [241]	validation_0-rmse:0.07254
# [242]	validation_0-rmse:0.07254
# [243]	validation_0-rmse:0.07254
# [244]	validation_0-rmse:0.07254
# [245]	validation_0-rmse:0.07254
# [246]	validation_0-rmse:0.07254
# [247]	validation_0-rmse:0.07254
# [248]	validation_0-rmse:0.07254
# [249]	validation_0-rmse:0.07254
# [250]	validation_0-rmse:0.07254
# [251]	validation_0-rmse:0.07254
# [252]	validation_0-rmse:0.07254
# [253]	validation_0-rmse:0.07254
# [254]	validation_0-rmse:0.07254
# [255]	validation_0-rmse:0.07254
# [256]	validation_0-rmse:0.07254
# [257]	validation_0-rmse:0.07254
# [258]	validation_0-rmse:0.07254
# [259]	validation_0-rmse:0.07254
# [260]	validation_0-rmse:0.07254
# [261]	validation_0-rmse:0.07254
# [262]	validation_0-rmse:0.07254
# [263]	validation_0-rmse:0.07254
# [264]	validation_0-rmse:0.07254
# [265]	validation_0-rmse:0.07254
# [266]	validation_0-rmse:0.07254
# [267]	validation_0-rmse:0.07254
# [268]	validation_0-rmse:0.07254
# [269]	validation_0-rmse:0.07254
# [270]	validation_0-rmse:0.07254
# [271]	validation_0-rmse:0.07254
# [272]	validation_0-rmse:0.07254
# [273]	validation_0-rmse:0.07254
# [274]	validation_0-rmse:0.07254
# [275]	validation_0-rmse:0.07254
# [276]	validation_0-rmse:0.07254
# [277]	validation_0-rmse:0.07254
# [278]	validation_0-rmse:0.07254
# [279]	validation_0-rmse:0.07254
# [280]	validation_0-rmse:0.07254
# [281]	validation_0-rmse:0.07254
# [282]	validation_0-rmse:0.07254
# [283]	validation_0-rmse:0.07254
# [284]	validation_0-rmse:0.07254
# [285]	validation_0-rmse:0.07254
# [286]	validation_0-rmse:0.07254
# [287]	validation_0-rmse:0.07254
# [288]	validation_0-rmse:0.07254
# [289]	validation_0-rmse:0.07254
# [290]	validation_0-rmse:0.07254
# [291]	validation_0-rmse:0.07254
# [292]	validation_0-rmse:0.07254
# [293]	validation_0-rmse:0.07254
# [294]	validation_0-rmse:0.07254
# [295]	validation_0-rmse:0.07254
# [296]	validation_0-rmse:0.07254
# [297]	validation_0-rmse:0.07254
# [298]	validation_0-rmse:0.07254
# [299]	validation_0-rmse:0.07254
# [300]	validation_0-rmse:0.07254
# [301]	validation_0-rmse:0.07254
# [302]	validation_0-rmse:0.07254
# [303]	validation_0-rmse:0.07254
# [304]	validation_0-rmse:0.07254
# [305]	validation_0-rmse:0.07254
# [306]	validation_0-rmse:0.07254
# [307]	validation_0-rmse:0.07254
# [308]	validation_0-rmse:0.07254
# [309]	validation_0-rmse:0.07254
# [310]	validation_0-rmse:0.07254
# [311]	validation_0-rmse:0.07254
# [312]	validation_0-rmse:0.07254
# [313]	validation_0-rmse:0.07254
# [314]	validation_0-rmse:0.07254
# [315]	validation_0-rmse:0.07254
# [316]	validation_0-rmse:0.07254
# [317]	validation_0-rmse:0.07254
# [318]	validation_0-rmse:0.07254
# [319]	validation_0-rmse:0.07254
# [320]	validation_0-rmse:0.07254
# [321]	validation_0-rmse:0.07254
# [322]	validation_0-rmse:0.07254
# [323]	validation_0-rmse:0.07254
# [324]	validation_0-rmse:0.07254
# [325]	validation_0-rmse:0.07254
# [326]	validation_0-rmse:0.07254
# [327]	validation_0-rmse:0.07254
# [328]	validation_0-rmse:0.07254
# [329]	validation_0-rmse:0.07254
# [330]	validation_0-rmse:0.07254
# [331]	validation_0-rmse:0.07254
# [332]	validation_0-rmse:0.07254
# [333]	validation_0-rmse:0.07254
# [334]	validation_0-rmse:0.07254
# [335]	validation_0-rmse:0.07254
# [336]	validation_0-rmse:0.07254
# [337]	validation_0-rmse:0.07254
# [338]	validation_0-rmse:0.07254
# [339]	validation_0-rmse:0.07254
# [340]	validation_0-rmse:0.07254
# [341]	validation_0-rmse:0.07254
# [342]	validation_0-rmse:0.07254
# [343]	validation_0-rmse:0.07254
# [344]	validation_0-rmse:0.07254
# [345]	validation_0-rmse:0.07254
# [346]	validation_0-rmse:0.07254
# [347]	validation_0-rmse:0.07254
# [348]	validation_0-rmse:0.07254
# [349]	validation_0-rmse:0.07254
# [350]	validation_0-rmse:0.07254
# [351]	validation_0-rmse:0.07254
# [352]	validation_0-rmse:0.07254
# [353]	validation_0-rmse:0.07254
# [354]	validation_0-rmse:0.07254
# [355]	validation_0-rmse:0.07254
# [356]	validation_0-rmse:0.07254
# [357]	validation_0-rmse:0.07254
# [358]	validation_0-rmse:0.07254
# [359]	validation_0-rmse:0.07254
# [360]	validation_0-rmse:0.07254
# [361]	validation_0-rmse:0.07254
# [362]	validation_0-rmse:0.07254
# [363]	validation_0-rmse:0.07254
# [364]	validation_0-rmse:0.07254
# [365]	validation_0-rmse:0.07254
# [366]	validation_0-rmse:0.07254
# [367]	validation_0-rmse:0.07254
# [368]	validation_0-rmse:0.07254
# [369]	validation_0-rmse:0.07254
# [370]	validation_0-rmse:0.07254
# [371]	validation_0-rmse:0.07254
# [372]	validation_0-rmse:0.07254
# [373]	validation_0-rmse:0.07254
# [374]	validation_0-rmse:0.07254
# [375]	validation_0-rmse:0.07254
# [376]	validation_0-rmse:0.07254
# [377]	validation_0-rmse:0.07254
# [378]	validation_0-rmse:0.07254
# [379]	validation_0-rmse:0.07254
# [380]	validation_0-rmse:0.07254
# [381]	validation_0-rmse:0.07254
# [382]	validation_0-rmse:0.07254
# [383]	validation_0-rmse:0.07254
# [384]	validation_0-rmse:0.07254
# [385]	validation_0-rmse:0.07254
# [386]	validation_0-rmse:0.07254
# [387]	validation_0-rmse:0.07254
# [388]	validation_0-rmse:0.07254
# [389]	validation_0-rmse:0.07254
# [390]	validation_0-rmse:0.07254
# [391]	validation_0-rmse:0.07254
# [392]	validation_0-rmse:0.07254
# [393]	validation_0-rmse:0.07254
# [394]	validation_0-rmse:0.07254
# [395]	validation_0-rmse:0.07254
# [396]	validation_0-rmse:0.07254
# [397]	validation_0-rmse:0.07254
# [398]	validation_0-rmse:0.07254
# [399]	validation_0-rmse:0.07254
# [400]	validation_0-rmse:0.07254
# [401]	validation_0-rmse:0.07254
# [402]	validation_0-rmse:0.07254
# [403]	validation_0-rmse:0.07254
# [404]	validation_0-rmse:0.07254
# [405]	validation_0-rmse:0.07254
# [406]	validation_0-rmse:0.07254
# [407]	validation_0-rmse:0.07254
# [408]	validation_0-rmse:0.07254
# [409]	validation_0-rmse:0.07254
# [410]	validation_0-rmse:0.07254
# [411]	validation_0-rmse:0.07254
# [412]	validation_0-rmse:0.07254
# [413]	validation_0-rmse:0.07254
# [414]	validation_0-rmse:0.07254
# [415]	validation_0-rmse:0.07254
# [416]	validation_0-rmse:0.07254
# [417]	validation_0-rmse:0.07254
# [418]	validation_0-rmse:0.07254
# [419]	validation_0-rmse:0.07254
# [420]	validation_0-rmse:0.07254
# [421]	validation_0-rmse:0.07254
# [422]	validation_0-rmse:0.07254
# [423]	validation_0-rmse:0.07254
# [424]	validation_0-rmse:0.07254
# [425]	validation_0-rmse:0.07254
# [426]	validation_0-rmse:0.07254
# [427]	validation_0-rmse:0.07254
# [428]	validation_0-rmse:0.07254
# [429]	validation_0-rmse:0.07254
# [430]	validation_0-rmse:0.07254
# [431]	validation_0-rmse:0.07254
# [432]	validation_0-rmse:0.07254
# [433]	validation_0-rmse:0.07254
# [434]	validation_0-rmse:0.07254
# [435]	validation_0-rmse:0.07254
# [436]	validation_0-rmse:0.07254
# [437]	validation_0-rmse:0.07254
# [438]	validation_0-rmse:0.07254
# [439]	validation_0-rmse:0.07254
# [440]	validation_0-rmse:0.07254
# [441]	validation_0-rmse:0.07254
# [442]	validation_0-rmse:0.07254
# [443]	validation_0-rmse:0.07254
# [444]	validation_0-rmse:0.07254
# [445]	validation_0-rmse:0.07254
# [446]	validation_0-rmse:0.07254
# [447]	validation_0-rmse:0.07254
# [448]	validation_0-rmse:0.07254
# [449]	validation_0-rmse:0.07254
# [450]	validation_0-rmse:0.07254
# [451]	validation_0-rmse:0.07254
# [452]	validation_0-rmse:0.07254
# [453]	validation_0-rmse:0.07254
# [454]	validation_0-rmse:0.07254
# [455]	validation_0-rmse:0.07254
# [456]	validation_0-rmse:0.07254
# [457]	validation_0-rmse:0.07254
# [458]	validation_0-rmse:0.07254
# [459]	validation_0-rmse:0.07254
# [460]	validation_0-rmse:0.07254
# [461]	validation_0-rmse:0.07254
# [462]	validation_0-rmse:0.07254
# [463]	validation_0-rmse:0.07254
# [464]	validation_0-rmse:0.07254
# [465]	validation_0-rmse:0.07254
# [466]	validation_0-rmse:0.07254
# [467]	validation_0-rmse:0.07254
# [468]	validation_0-rmse:0.07254
# [469]	validation_0-rmse:0.07254
# [470]	validation_0-rmse:0.07254
# [471]	validation_0-rmse:0.07254
# [472]	validation_0-rmse:0.07254
# [473]	validation_0-rmse:0.07254
# [474]	validation_0-rmse:0.07254
# [475]	validation_0-rmse:0.07254
# [476]	validation_0-rmse:0.07254
# [477]	validation_0-rmse:0.07254
# [478]	validation_0-rmse:0.07254
# [479]	validation_0-rmse:0.07254
# [480]	validation_0-rmse:0.07254
# [481]	validation_0-rmse:0.07254
# [482]	validation_0-rmse:0.07254
# [483]	validation_0-rmse:0.07254
# [484]	validation_0-rmse:0.07254
# [485]	validation_0-rmse:0.07254
# [486]	validation_0-rmse:0.07254
# [487]	validation_0-rmse:0.07254
# [488]	validation_0-rmse:0.07254
# [489]	validation_0-rmse:0.07254
# [490]	validation_0-rmse:0.07254
# [491]	validation_0-rmse:0.07254
# [492]	validation_0-rmse:0.07254
# [493]	validation_0-rmse:0.07254
# [494]	validation_0-rmse:0.07254
# [495]	validation_0-rmse:0.07254
# [496]	validation_0-rmse:0.07254
# [497]	validation_0-rmse:0.07254
# [498]	validation_0-rmse:0.07254
# [499]	validation_0-rmse:0.07254
# [500]	validation_0-rmse:0.07254
# [501]	validation_0-rmse:0.07254
# [502]	validation_0-rmse:0.07254
# [503]	validation_0-rmse:0.07254
# [504]	validation_0-rmse:0.07254
# [505]	validation_0-rmse:0.07254
# [506]	validation_0-rmse:0.07254
# [507]	validation_0-rmse:0.07254
# [508]	validation_0-rmse:0.07254
# [509]	validation_0-rmse:0.07254
# [510]	validation_0-rmse:0.07254
# [511]	validation_0-rmse:0.07254
# [512]	validation_0-rmse:0.07254
# [513]	validation_0-rmse:0.07254
# [514]	validation_0-rmse:0.07254
# [515]	validation_0-rmse:0.07254
# [516]	validation_0-rmse:0.07254
# [517]	validation_0-rmse:0.07254
# [518]	validation_0-rmse:0.07254
# [519]	validation_0-rmse:0.07254
# [520]	validation_0-rmse:0.07254
# [521]	validation_0-rmse:0.07254
# [522]	validation_0-rmse:0.07254
# [523]	validation_0-rmse:0.07254
# [524]	validation_0-rmse:0.07254
# [525]	validation_0-rmse:0.07254
# [526]	validation_0-rmse:0.07254
# [527]	validation_0-rmse:0.07254
# [528]	validation_0-rmse:0.07254
# [529]	validation_0-rmse:0.07254
# [530]	validation_0-rmse:0.07254
# [531]	validation_0-rmse:0.07254
# [532]	validation_0-rmse:0.07254
# [533]	validation_0-rmse:0.07254
# [534]	validation_0-rmse:0.07254
# [535]	validation_0-rmse:0.07254
# [536]	validation_0-rmse:0.07254
# [537]	validation_0-rmse:0.07254
# [538]	validation_0-rmse:0.07254
# [539]	validation_0-rmse:0.07254
# [540]	validation_0-rmse:0.07254
# [541]	validation_0-rmse:0.07254
# [542]	validation_0-rmse:0.07254
# [543]	validation_0-rmse:0.07254
# [544]	validation_0-rmse:0.07254
# [545]	validation_0-rmse:0.07254
# [546]	validation_0-rmse:0.07254
# [547]	validation_0-rmse:0.07254
# [548]	validation_0-rmse:0.07254
# [549]	validation_0-rmse:0.07254
# [550]	validation_0-rmse:0.07254
# [551]	validation_0-rmse:0.07254
# [552]	validation_0-rmse:0.07254
# [553]	validation_0-rmse:0.07254
# [554]	validation_0-rmse:0.07254
# [555]	validation_0-rmse:0.07254
# [556]	validation_0-rmse:0.07254
# [557]	validation_0-rmse:0.07254
# [558]	validation_0-rmse:0.07254
# [559]	validation_0-rmse:0.07254
# [560]	validation_0-rmse:0.07254
# [561]	validation_0-rmse:0.07254
# [562]	validation_0-rmse:0.07254
# [563]	validation_0-rmse:0.07254
# [564]	validation_0-rmse:0.07254
# [565]	validation_0-rmse:0.07254
# [566]	validation_0-rmse:0.07254
# [567]	validation_0-rmse:0.07254
# [568]	validation_0-rmse:0.07254
# [569]	validation_0-rmse:0.07254
# [570]	validation_0-rmse:0.07254
# [571]	validation_0-rmse:0.07254
# [572]	validation_0-rmse:0.07254
# [573]	validation_0-rmse:0.07254
# [574]	validation_0-rmse:0.07254
# [575]	validation_0-rmse:0.07254
# [576]	validation_0-rmse:0.07254
# [577]	validation_0-rmse:0.07254
# [578]	validation_0-rmse:0.07254
# [579]	validation_0-rmse:0.07254
# [580]	validation_0-rmse:0.07254
# [581]	validation_0-rmse:0.07254
# [582]	validation_0-rmse:0.07254
# [583]	validation_0-rmse:0.07254
# [584]	validation_0-rmse:0.07254
# [585]	validation_0-rmse:0.07254
# [586]	validation_0-rmse:0.07254
# [587]	validation_0-rmse:0.07254
# [588]	validation_0-rmse:0.07254
# [589]	validation_0-rmse:0.07254
# [590]	validation_0-rmse:0.07254
# [591]	validation_0-rmse:0.07254
# [592]	validation_0-rmse:0.07254
# [593]	validation_0-rmse:0.07254
# [594]	validation_0-rmse:0.07254
# [595]	validation_0-rmse:0.07254
# [596]	validation_0-rmse:0.07254
# [597]	validation_0-rmse:0.07254
# [598]	validation_0-rmse:0.07254
# [599]	validation_0-rmse:0.07254
# [600]	validation_0-rmse:0.07254
# [601]	validation_0-rmse:0.07254
# [602]	validation_0-rmse:0.07254
# [603]	validation_0-rmse:0.07254
# [604]	validation_0-rmse:0.07254
# [605]	validation_0-rmse:0.07254
# [606]	validation_0-rmse:0.07254
# [607]	validation_0-rmse:0.07254
# [608]	validation_0-rmse:0.07254
# [609]	validation_0-rmse:0.07254
# [610]	validation_0-rmse:0.07254
# [611]	validation_0-rmse:0.07254
# [612]	validation_0-rmse:0.07254
# [613]	validation_0-rmse:0.07254
# [614]	validation_0-rmse:0.07254
# [615]	validation_0-rmse:0.07254
# [616]	validation_0-rmse:0.07254
# [617]	validation_0-rmse:0.07254
# [618]	validation_0-rmse:0.07254
# [619]	validation_0-rmse:0.07254
# [620]	validation_0-rmse:0.07254
# [621]	validation_0-rmse:0.07254
# [622]	validation_0-rmse:0.07254
# [623]	validation_0-rmse:0.07254
# [624]	validation_0-rmse:0.07254
# [625]	validation_0-rmse:0.07254
# [626]	validation_0-rmse:0.07254
# [627]	validation_0-rmse:0.07254
# [628]	validation_0-rmse:0.07254
# [629]	validation_0-rmse:0.07254
# [630]	validation_0-rmse:0.07254
# [631]	validation_0-rmse:0.07254
# [632]	validation_0-rmse:0.07254
# [633]	validation_0-rmse:0.07254
# [634]	validation_0-rmse:0.07254
# [635]	validation_0-rmse:0.07254
# [636]	validation_0-rmse:0.07254
# [637]	validation_0-rmse:0.07254
# [638]	validation_0-rmse:0.07254
# [639]	validation_0-rmse:0.07254
# [640]	validation_0-rmse:0.07254
# [641]	validation_0-rmse:0.07254
# [642]	validation_0-rmse:0.07254
# [643]	validation_0-rmse:0.07254
# [644]	validation_0-rmse:0.07254
# [645]	validation_0-rmse:0.07254
# [646]	validation_0-rmse:0.07254
# [647]	validation_0-rmse:0.07254
# [648]	validation_0-rmse:0.07254
# [649]	validation_0-rmse:0.07254
# [650]	validation_0-rmse:0.07254
# [651]	validation_0-rmse:0.07254
# [652]	validation_0-rmse:0.07254
# [653]	validation_0-rmse:0.07254
# [654]	validation_0-rmse:0.07254
# [655]	validation_0-rmse:0.07254
# [656]	validation_0-rmse:0.07254
# [657]	validation_0-rmse:0.07254
# [658]	validation_0-rmse:0.07254
# [659]	validation_0-rmse:0.07254
# [660]	validation_0-rmse:0.07254
# [661]	validation_0-rmse:0.07254
# [662]	validation_0-rmse:0.07254
# [663]	validation_0-rmse:0.07254
# [664]	validation_0-rmse:0.07254
# [665]	validation_0-rmse:0.07254
# [666]	validation_0-rmse:0.07254
# [667]	validation_0-rmse:0.07254
# [668]	validation_0-rmse:0.07254
# [669]	validation_0-rmse:0.07254
# [670]	validation_0-rmse:0.07254
# [671]	validation_0-rmse:0.07254
# [672]	validation_0-rmse:0.07254
# [673]	validation_0-rmse:0.07254
# [674]	validation_0-rmse:0.07254
# [675]	validation_0-rmse:0.07254
# [676]	validation_0-rmse:0.07254
# [677]	validation_0-rmse:0.07254
# [678]	validation_0-rmse:0.07254
# [679]	validation_0-rmse:0.07254
# [680]	validation_0-rmse:0.07254
# [681]	validation_0-rmse:0.07254
# [682]	validation_0-rmse:0.07254
# [683]	validation_0-rmse:0.07254
# [684]	validation_0-rmse:0.07254
# [685]	validation_0-rmse:0.07254
# [686]	validation_0-rmse:0.07254
# [687]	validation_0-rmse:0.07254
# [688]	validation_0-rmse:0.07254
# [689]	validation_0-rmse:0.07254
# [690]	validation_0-rmse:0.07254
# [691]	validation_0-rmse:0.07254
# [692]	validation_0-rmse:0.07254
# [693]	validation_0-rmse:0.07254
# [694]	validation_0-rmse:0.07254
# [695]	validation_0-rmse:0.07254
# [696]	validation_0-rmse:0.07254
# [697]	validation_0-rmse:0.07254
# [698]	validation_0-rmse:0.07254
# [699]	validation_0-rmse:0.07254
# [700]	validation_0-rmse:0.07254
# [701]	validation_0-rmse:0.07254
# [702]	validation_0-rmse:0.07254
# [703]	validation_0-rmse:0.07254
# [704]	validation_0-rmse:0.07254
# [705]	validation_0-rmse:0.07254
# [706]	validation_0-rmse:0.07254
# [707]	validation_0-rmse:0.07254
# [708]	validation_0-rmse:0.07254
# [709]	validation_0-rmse:0.07254
# [710]	validation_0-rmse:0.07254
# [711]	validation_0-rmse:0.07254
# [712]	validation_0-rmse:0.07254
# [713]	validation_0-rmse:0.07254
# [714]	validation_0-rmse:0.07254
# [715]	validation_0-rmse:0.07254
# [716]	validation_0-rmse:0.07254
# [717]	validation_0-rmse:0.07254
# [718]	validation_0-rmse:0.07254
# [719]	validation_0-rmse:0.07254
# [720]	validation_0-rmse:0.07254
# [721]	validation_0-rmse:0.07254
# [722]	validation_0-rmse:0.07254
# [723]	validation_0-rmse:0.07254
# [724]	validation_0-rmse:0.07254
# [725]	validation_0-rmse:0.07254
# [726]	validation_0-rmse:0.07254
# [727]	validation_0-rmse:0.07254
# [728]	validation_0-rmse:0.07254
# [729]	validation_0-rmse:0.07254
# [730]	validation_0-rmse:0.07254
# [731]	validation_0-rmse:0.07254
# [732]	validation_0-rmse:0.07254
# [733]	validation_0-rmse:0.07254
# [734]	validation_0-rmse:0.07254
# [735]	validation_0-rmse:0.07254
# [736]	validation_0-rmse:0.07254
# [737]	validation_0-rmse:0.07254
# [738]	validation_0-rmse:0.07254
# [739]	validation_0-rmse:0.07254
# [740]	validation_0-rmse:0.07254
# [741]	validation_0-rmse:0.07254
# [742]	validation_0-rmse:0.07254
# [743]	validation_0-rmse:0.07254
# [744]	validation_0-rmse:0.07254
# [745]	validation_0-rmse:0.07254
# [746]	validation_0-rmse:0.07254
# [747]	validation_0-rmse:0.07254
# [748]	validation_0-rmse:0.07254
# [749]	validation_0-rmse:0.07254
# [750]	validation_0-rmse:0.07254
# [751]	validation_0-rmse:0.07254
# [752]	validation_0-rmse:0.07254
# [753]	validation_0-rmse:0.07254
# [754]	validation_0-rmse:0.07254
# [755]	validation_0-rmse:0.07254
# [756]	validation_0-rmse:0.07254
# [757]	validation_0-rmse:0.07254
# [758]	validation_0-rmse:0.07254
# [759]	validation_0-rmse:0.07254
# [760]	validation_0-rmse:0.07254
# [761]	validation_0-rmse:0.07254
# [762]	validation_0-rmse:0.07254
# [763]	validation_0-rmse:0.07254
# [764]	validation_0-rmse:0.07254
# [765]	validation_0-rmse:0.07254
# [766]	validation_0-rmse:0.07254
# [767]	validation_0-rmse:0.07254
# [768]	validation_0-rmse:0.07254
# [769]	validation_0-rmse:0.07254
# [770]	validation_0-rmse:0.07254
# [771]	validation_0-rmse:0.07254
# [772]	validation_0-rmse:0.07254
# [773]	validation_0-rmse:0.07254
# [774]	validation_0-rmse:0.07254
# [775]	validation_0-rmse:0.07254
# [776]	validation_0-rmse:0.07254
# [777]	validation_0-rmse:0.07254
# [778]	validation_0-rmse:0.07254
# [779]	validation_0-rmse:0.07254
# [780]	validation_0-rmse:0.07254
# [781]	validation_0-rmse:0.07254
# [782]	validation_0-rmse:0.07254
# [783]	validation_0-rmse:0.07254
# [784]	validation_0-rmse:0.07254
# [785]	validation_0-rmse:0.07254
# [786]	validation_0-rmse:0.07254
# [787]	validation_0-rmse:0.07254
# [788]	validation_0-rmse:0.07254
# [789]	validation_0-rmse:0.07254
# [790]	validation_0-rmse:0.07254
# [791]	validation_0-rmse:0.07254
# [792]	validation_0-rmse:0.07254
# [793]	validation_0-rmse:0.07254
# [794]	validation_0-rmse:0.07254
# [795]	validation_0-rmse:0.07254
# [796]	validation_0-rmse:0.07254
# [797]	validation_0-rmse:0.07254
# [798]	validation_0-rmse:0.07254
# [799]	validation_0-rmse:0.07254
# [800]	validation_0-rmse:0.07254
# [801]	validation_0-rmse:0.07254
# [802]	validation_0-rmse:0.07254
# [803]	validation_0-rmse:0.07254
# [804]	validation_0-rmse:0.07254
# [805]	validation_0-rmse:0.07254
# [806]	validation_0-rmse:0.07254
# [807]	validation_0-rmse:0.07254
# [808]	validation_0-rmse:0.07254
# [809]	validation_0-rmse:0.07254
# [810]	validation_0-rmse:0.07254
# [811]	validation_0-rmse:0.07254
# [812]	validation_0-rmse:0.07254
# [813]	validation_0-rmse:0.07254
# [814]	validation_0-rmse:0.07254
# [815]	validation_0-rmse:0.07254
# [816]	validation_0-rmse:0.07254
# [817]	validation_0-rmse:0.07254
# [818]	validation_0-rmse:0.07254
# [819]	validation_0-rmse:0.07254
# [820]	validation_0-rmse:0.07254
# [821]	validation_0-rmse:0.07254
# [822]	validation_0-rmse:0.07254
# [823]	validation_0-rmse:0.07254
# [824]	validation_0-rmse:0.07254
# [825]	validation_0-rmse:0.07254
# [826]	validation_0-rmse:0.07254
# [827]	validation_0-rmse:0.07254
# [828]	validation_0-rmse:0.07254
# [829]	validation_0-rmse:0.07254
# [830]	validation_0-rmse:0.07254
# [831]	validation_0-rmse:0.07254
# [832]	validation_0-rmse:0.07254
# [833]	validation_0-rmse:0.07254
# [834]	validation_0-rmse:0.07254
# [835]	validation_0-rmse:0.07254
# [836]	validation_0-rmse:0.07254
# [837]	validation_0-rmse:0.07254
# [838]	validation_0-rmse:0.07254
# [839]	validation_0-rmse:0.07254
# [840]	validation_0-rmse:0.07254
# [841]	validation_0-rmse:0.07254
# [842]	validation_0-rmse:0.07254
# [843]	validation_0-rmse:0.07254
# [844]	validation_0-rmse:0.07254
# [845]	validation_0-rmse:0.07254
# [846]	validation_0-rmse:0.07254
# [847]	validation_0-rmse:0.07254
# [848]	validation_0-rmse:0.07254
# [849]	validation_0-rmse:0.07254
# [850]	validation_0-rmse:0.07254
# [851]	validation_0-rmse:0.07254
# [852]	validation_0-rmse:0.07254
# [853]	validation_0-rmse:0.07254
# [854]	validation_0-rmse:0.07254
# [855]	validation_0-rmse:0.07254
# [856]	validation_0-rmse:0.07254
# [857]	validation_0-rmse:0.07254
# [858]	validation_0-rmse:0.07254
# [859]	validation_0-rmse:0.07254
# [860]	validation_0-rmse:0.07254
# [861]	validation_0-rmse:0.07254
# [862]	validation_0-rmse:0.07254
# [863]	validation_0-rmse:0.07254
# [864]	validation_0-rmse:0.07254
# [865]	validation_0-rmse:0.07254
# [866]	validation_0-rmse:0.07254
# [867]	validation_0-rmse:0.07254
# [868]	validation_0-rmse:0.07254
# [869]	validation_0-rmse:0.07254
# [870]	validation_0-rmse:0.07254
# [871]	validation_0-rmse:0.07254
# [872]	validation_0-rmse:0.07254
# [873]	validation_0-rmse:0.07254
# [874]	validation_0-rmse:0.07254
# [875]	validation_0-rmse:0.07254
# [876]	validation_0-rmse:0.07254
# [877]	validation_0-rmse:0.07254
# [878]	validation_0-rmse:0.07254
# [879]	validation_0-rmse:0.07254
# [880]	validation_0-rmse:0.07254
# [881]	validation_0-rmse:0.07254
# [882]	validation_0-rmse:0.07254
# [883]	validation_0-rmse:0.07254
# [884]	validation_0-rmse:0.07254
# [885]	validation_0-rmse:0.07254
# [886]	validation_0-rmse:0.07254
# [887]	validation_0-rmse:0.07254
# [888]	validation_0-rmse:0.07254
# [889]	validation_0-rmse:0.07254
# [890]	validation_0-rmse:0.07254
# [891]	validation_0-rmse:0.07254
# [892]	validation_0-rmse:0.07254
# [893]	validation_0-rmse:0.07254
# [894]	validation_0-rmse:0.07254
# [895]	validation_0-rmse:0.07254
# [896]	validation_0-rmse:0.07254
# [897]	validation_0-rmse:0.07254
# [898]	validation_0-rmse:0.07254
# [899]	validation_0-rmse:0.07254
# [900]	validation_0-rmse:0.07254
# [901]	validation_0-rmse:0.07254
# [902]	validation_0-rmse:0.07254
# [903]	validation_0-rmse:0.07254
# [904]	validation_0-rmse:0.07254
# [905]	validation_0-rmse:0.07254
# [906]	validation_0-rmse:0.07254
# [907]	validation_0-rmse:0.07254
# [908]	validation_0-rmse:0.07254
# [909]	validation_0-rmse:0.07254
# [910]	validation_0-rmse:0.07254
# [911]	validation_0-rmse:0.07254
# [912]	validation_0-rmse:0.07254
# [913]	validation_0-rmse:0.07254
# [914]	validation_0-rmse:0.07254
# [915]	validation_0-rmse:0.07254
# [916]	validation_0-rmse:0.07254
# [917]	validation_0-rmse:0.07254
# [918]	validation_0-rmse:0.07254
# [919]	validation_0-rmse:0.07254
# [920]	validation_0-rmse:0.07254
# [921]	validation_0-rmse:0.07254
# [922]	validation_0-rmse:0.07254
# [923]	validation_0-rmse:0.07254
# [924]	validation_0-rmse:0.07254
# [925]	validation_0-rmse:0.07254
# [926]	validation_0-rmse:0.07254
# [927]	validation_0-rmse:0.07254
# [928]	validation_0-rmse:0.07254
# [929]	validation_0-rmse:0.07254
# [930]	validation_0-rmse:0.07254
# [931]	validation_0-rmse:0.07254
# [932]	validation_0-rmse:0.07254
# [933]	validation_0-rmse:0.07254
# [934]	validation_0-rmse:0.07254
# [935]	validation_0-rmse:0.07254
# [936]	validation_0-rmse:0.07254
# [937]	validation_0-rmse:0.07254
# [938]	validation_0-rmse:0.07254
# [939]	validation_0-rmse:0.07254
# [940]	validation_0-rmse:0.07254
# [941]	validation_0-rmse:0.07254
# [942]	validation_0-rmse:0.07254
# [943]	validation_0-rmse:0.07254
# [944]	validation_0-rmse:0.07254
# [945]	validation_0-rmse:0.07254
# [946]	validation_0-rmse:0.07254
# [947]	validation_0-rmse:0.07254
# [948]	validation_0-rmse:0.07254
# [949]	validation_0-rmse:0.07254
# [950]	validation_0-rmse:0.07254
# [951]	validation_0-rmse:0.07254
# [952]	validation_0-rmse:0.07254
# [953]	validation_0-rmse:0.07254
# [954]	validation_0-rmse:0.07254
# [955]	validation_0-rmse:0.07254
# [956]	validation_0-rmse:0.07254
# [957]	validation_0-rmse:0.07254
# [958]	validation_0-rmse:0.07254
# [959]	validation_0-rmse:0.07254
# [960]	validation_0-rmse:0.07254
# [961]	validation_0-rmse:0.07254
# [962]	validation_0-rmse:0.07254
# [963]	validation_0-rmse:0.07254
# [964]	validation_0-rmse:0.07254
# [965]	validation_0-rmse:0.07254
# [966]	validation_0-rmse:0.07254
# [967]	validation_0-rmse:0.07254
# [968]	validation_0-rmse:0.07254
# [969]	validation_0-rmse:0.07254
# [970]	validation_0-rmse:0.07254
# [971]	validation_0-rmse:0.07254
# [972]	validation_0-rmse:0.07254
# [973]	validation_0-rmse:0.07254
# [974]	validation_0-rmse:0.07254
# [975]	validation_0-rmse:0.07254
# [976]	validation_0-rmse:0.07254
# [977]	validation_0-rmse:0.07254
# [978]	validation_0-rmse:0.07254
# [979]	validation_0-rmse:0.07254
# [980]	validation_0-rmse:0.07254
# [981]	validation_0-rmse:0.07254
# [982]	validation_0-rmse:0.07254
# [983]	validation_0-rmse:0.07254
# [984]	validation_0-rmse:0.07254
# [985]	validation_0-rmse:0.07254
# [986]	validation_0-rmse:0.07254
# [987]	validation_0-rmse:0.07254
# [988]	validation_0-rmse:0.07254
# [989]	validation_0-rmse:0.07254
# [990]	validation_0-rmse:0.07254
# [991]	validation_0-rmse:0.07254
# [992]	validation_0-rmse:0.07254
# [993]	validation_0-rmse:0.07254
# [994]	validation_0-rmse:0.07254
# [995]	validation_0-rmse:0.07254
# [996]	validation_0-rmse:0.07254
# [997]	validation_0-rmse:0.07254
# [998]	validation_0-rmse:0.07254
# [999]	validation_0-rmse:0.07254

# %%
submission
# Out:
#          num_date_time       answer
# 0        1_20220825 00  2038.643738
# 1        1_20220825 01  1974.402954
# 2        1_20220825 02  1744.126099
# 3        1_20220825 03  1560.389130
# 4        1_20220825 04  1600.776733
# ...                ...          ...
# 16795  100_20220831 19   945.136520
# 16796  100_20220831 20   820.907761
# 16797  100_20220831 21   730.127701
# 16798  100_20220831 22   601.146713
# 16799  100_20220831 23   517.041122
#
# [16800 rows x 2 columns]

# %%
submission.to_csv('../submission/answer13.csv', index = False) # 파일 저장

# %%
best = pd.read_csv('../submission/answer12.csv')
update = pd.read_csv('../submission/answer13.csv')

# %%
display(best)
display(update)
# Out:
#          num_date_time       answer
# 0        1_20220825 00  1964.406297
# 1        1_20220825 01  1868.603542
# 2        1_20220825 02  1698.213004
# 3        1_20220825 03  1611.891991
# 4        1_20220825 04  1608.727523
# ...                ...          ...
# 16795  100_20220831 19   959.004612
# 16796  100_20220831 20   864.906644
# 16797  100_20220831 21   771.612402
# 16798  100_20220831 22   676.423301
# 16799  100_20220831 23   541.681877
#
# [16800 rows x 2 columns]
#          num_date_time       answer
# 0        1_20220825 00  2038.643738
# 1        1_20220825 01  1974.402954
# 2        1_20220825 02  1744.126099
# 3        1_20220825 03  1560.389130
# 4        1_20220825 04  1600.776733
# ...                ...          ...
# 16795  100_20220831 19   945.136520
# 16796  100_20220831 20   820.907761
# 16797  100_20220831 21   730.127701
# 16798  100_20220831 22   601.146713
# 16799  100_20220831 23   517.041122
#
# [16800 rows x 2 columns]

# %%
x = np.array(best['num_date_time'])
y = np.array(best['answer'])


x_ = np.array(update['num_date_time'])
y_ = np.array(update['answer'])

plt.figure(figsize = (30, 15))
plt.plot(x, y)
plt.plot(x_, y_)
# Out:
# Error in callback <function flush_figures at 0x00000259AC4688B0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2253                 # force the figure dpi to 72), so we need to set it again here.
#    2254                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255                     result = print_method(
#    2256                         filename,
#    2257                         facecolor=facecolor,
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     506             *metadata*, including the default 'Software' key.
#     507         """
# --> 508         FigureCanvasAgg.draw(self)
#     509         mpl.image.imsave(
#     510             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     404              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     405               else nullcontext()):
# --> 406             self.figure.draw(self.renderer)
#     407             # A GUI class may be need to update a window using this draw, so
#     408             # don't forget to call the superclass.
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    2788
#    2789             self.patch.draw(renderer)
# -> 2790             mimage._draw_list_compositing_images(
#    2791                 renderer, self, artists, self.suppressComposite)
#    2792
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2919             renderer.stop_rasterizing()
#    2920
# -> 2921         mimage._draw_list_compositing_images(renderer, self, artists)
#    2922
#    2923         renderer.close_group('axes')
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1151         # the actual bbox
#    1152
# -> 1153         self._update_label_position(renderer)
#    1154
#    1155         self.label.draw(renderer)
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\axis.py in _update_label_position(self, renderer)
#    2094                 # use axes if spine doesn't exist
#    2095                 spinebbox = self.axes.bbox
# -> 2096             bbox = mtransforms.Bbox.union(bboxes + [spinebbox])
#    2097             bottom = bbox.y0
#    2098
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\transforms.py in union(bboxes)
#     681         x1 = np.max([bbox.xmax for bbox in bboxes])
#     682         y0 = np.min([bbox.ymin for bbox in bboxes])
# --> 683         y1 = np.max([bbox.ymax for bbox in bboxes])
#     684         return Bbox([[x0, y0], [x1, y1]])
#     685
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\transforms.py in <listcomp>(.0)
#     681         x1 = np.max([bbox.xmax for bbox in bboxes])
#     682         y0 = np.min([bbox.ymin for bbox in bboxes])
# --> 683         y1 = np.max([bbox.ymax for bbox in bboxes])
#     684         return Bbox([[x0, y0], [x1, y1]])
#     685
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\matplotlib\transforms.py in ymax(self)
#     342     def ymax(self):
#     343         """The top edge of the bounding box."""
# --> 344         return np.max(self.get_points()[:, 1])
#     345
#     346     @property
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# c:\Users\LimJaeSung\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2731     5
#    2732     """
# -> 2733     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2734                           keepdims=keepdims, initial=initial, where=where)
#    2735
#
# KeyboardInterrupt:
